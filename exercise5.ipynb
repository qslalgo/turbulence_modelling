# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Create a rectangle (lower-left corner at (1, 1), width=4, height=2)
rectangle = plt.Rectangle((1, 1), 4, 2, edgecolor='blue', facecolor='lightblue')

# Set up plot
fig, ax = plt.subplots()
ax.add_patch(rectangle)

# Set axis limits and labels
ax.set_xlim(0, 6)
ax.set_ylim(0, 5)
ax.set_aspect('equal')  # Keep aspect ratio square
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Rectangle Plot')

plt.grid(True)  # Optional: Add grid
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the figure and axis
fig, ax = plt.subplots()

# Draw the rectangle representing the boundary
plt.plot([-0.5, 2, 2, -0.5, -0.5], [0, 0, 1, 1, 0], 'r')

# Axis labels
plt.xlabel("x")
plt.ylabel("y")

# Boundary condition annotations
plt.text(0.8, 0.8, "farfield Riemann BC", ha='right')
plt.text(1., 0.8, f"P/P_ref = 1.0,\nother quantities\nfrom interior", va='center')
#plt.text(-0.05, 0.5, "Pt/P_ref=1.02828,\nTt/T_ref = 1.008,\n1 quantity from interior", va='center', ha='right')
plt.text(1, 0.2, "adiabatic solid wall", ha='center')
#plt.text(0, -0.15, "start of plate at x=0", ha='center')
plt.text(-0.25, 0.2, "symmetry", ha='center')


# Annotations with arrows
ax.annotate('', xy=(-0.25, 0.2), xytext=(-0.25, 0.05), arrowprops=dict(arrowstyle='<-'))
ax.annotate('start of plate at x=0', xy=(0, 0), xytext=(0.1, -0.15), arrowprops=dict(arrowstyle='->'))

ax.annotate('', xy=(0.35, 0.85), xytext=(0.35,1), arrowprops=dict(arrowstyle='<-'))
ax.annotate('', xy=(1, 0.2), xytext=(1, 0.05),arrowprops=dict(arrowstyle='<-'))
ax.annotate(r'$P_t/P_{ref} = 1.02828,$' + '\n' + r'$T_t/T_{ref} = 1.008,$' + '\n1 quantity from interior',
            xy=(-0.5, 0.6), xytext=(-0.2, 0.5), arrowprops=dict(arrowstyle='->'))

ax.annotate(r'',
            xy=(1.8, 0.8), xytext=(2, 0.8), arrowprops=dict(arrowstyle='<-'))

ax.annotate(r'',
            xy=(-0.49, 0.05), xytext=(0.01, 0.05), arrowprops=dict(arrowstyle='<->'))

ax.annotate(r'',
            xy=(0., 0.05), xytext=(2.01, 0.05), arrowprops=dict(arrowstyle='<->'))


# Title
plt.text(0.9, 1.2, r"Flat Plate Boundary Conditions, M=0.2, $R_{e,L}$ = 5 million (L=1), $T_{ref}$ = 540 R", ha='center')

# Set axis limits
plt.xlim(-1, 2.5)
plt.ylim(-0.2, 1.3)

# Turn off the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.grid(False)
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_excel('worksheet_exer5.xlsx')

# %%
df.columns
# Out:
# Index(['y', 'y+ ', 'u+', 'y+ theo', 'u+theo', 'Unnamed: 5', 'Unnamed: 6',
#        'y.1', 'x02', 'x04', 'x06', 'Unnamed: 11', 'y2', 'x=0.2', 'x=0.4',
#        'x=0.6', 'Unnamed: 16', 'y1+ ', 'u1+', 'Unnamed: 19', 'y+ec', 'u+ec',
#        'Unnamed: 22', 'y+oc ', 'u+oc', 'Unnamed: 25', 'y+ef ', 'u+ef',
#        'Unnamed: 28', 'y+of', 'u+of', 'Unnamed: 31', 'y+earsmc', 'u+earsmc'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

#
    0.00236432, 0.00235980, 0.00235534, 0.00235095, 0.00234660, 0.00234232, 0.00233809, 0.00233392, 0.00232980, 0.00232574
]

# Original data
Re_theta = [2.50E+03, 4.17E+03, 7.01E+03, 9.62E+03, 1.45E+04, 1.99E+04]
c_f = [0.008179465, 0.007062474, 0.006132971, 0.005669671, 0.005165414, 0.004784077]
						
Re_theta2 = [1.10E+03,	1.94E+03,	3.40E+03,	4.76E+03,	7.34E+03,	1.03E+04]
						
						
						
tau_wall2 = [10.8462,	9.75079,	8.76245,	8.25044,	7.68113,	7.24159]
						
						
						
c_f2 = [	0.003908237,	0.003509213,	0.003149396,	0.002962586,	0.002753836,	0.002591821]


# Plotting both datasets
plt.plot(Re_theta, c_f, marker='o', linestyle='-', color='g', label='Mixing Length Model')
plt.plot(Re_theta2, c_f2, marker='o', linestyle='-', color='b', label='One Equation Model')
plt.plot(Re_theo, c_f_theo, marker='x', linestyle='--', color='r', label='Theoretical Data')

# Labels and title
plt.xlabel(r'$R_{e, \theta}$')
plt.ylabel(r'$C_f$')
plt.title(r'Plot of $C_f$ vs $R_{e, \theta}$')

plt.xlim(4000, 12000)

# Display grid
plt.grid(True)

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.plot(df['y+ '], df['u+'], linestyle='-', color='g', label=r'Mixing Length Model ($y^+, u^+$)')
plt.plot(df['y1+ '], df['u1+'], linestyle='-', color='b', label=r'One-Equation Model ($y^+, u^+$)')
plt.plot(df['y+ theo'], df['u+theo'],  linestyle='--', color='r', label=r'Theoretical ($y^+_{theo}, u^+_{theo}$)')

# Log scale for better visualization (optional for boundary layer profiles)
plt.xscale('log')

# Axis labels and title
plt.xlabel('y+ (Dimensionless Wall Distance)')
plt.ylabel('u+ (Dimensionless Velocity)')
plt.title(r'Comparison of Experimental and Theoretical $u^+$ vs $y^+$')

# Add legend and grid
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.plot(df['y2'], df['x=0.2'], marker='o', linestyle='-', color='b', label=r'Simulation x=0.2')
plt.plot(df['y2'], df['x=0.4'], marker='x', linestyle='--', color='r', label=r'Simualtion x=0.4')
plt.plot(df['y2'], df['x=0.6'], marker='^', linestyle='--', color='g', label=r'Simualtion x=0.6')



# Axis labels and title
plt.xlabel('Distance from the Wall (m)')
plt.ylabel('Turbulent Viscosity [kg/(ms)]')
plt.title('Comparison of Eddy Viscostiy for Different Positions in the Grid')

# Add legend and grid
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Show the plot
plt.show()

# %%
from matplotlib import lines
import matplotlib.pyplot as plt
from pyparsing import line, lineStart

# Original data
Re_theta = [1.14E+03,	2.04E+03,	3.58E+03,	5.02E+03,	7.75E+03,	1.09E+04
]
c_f = [0.004201492,	0.003733415,	0.00333597,	0.003134027,	0.002912876,	0.002739271
]

# New theoretical data
Re_theo = [
    200.000, 400.000, 600.000, 800.000, 1000.000, 1200.000, 1400.000, 1600.000, 1800.000, 2000.000,
    2200.000, 2400.000, 2600.000, 2800.000, 3000.000, 3200.000, 3400.000, 3600.000, 3800.000, 4000.000,
    4200.000, 4400.000, 4600.000, 4800.000, 5000.000, 5200.000, 5400.000, 5600.000, 5800.000, 6000.000,
c_f_ml = [0.008179465, 0.007062474, 0.006132971, 0.005669671, 0.005165414, 0.004784077]
						
Re_theta_sa = [1.10E+03,	1.94E+03,	3.40E+03,	4.76E+03,	7.34E+03,	1.03E+04]
						
						
						
tau_wall2 = [10.8462,	9.75079,	8.76245,	8.25044,	7.68113,	7.24159]
						
						
						
c_f_sa = [	0.003908237,	0.003509213,	0.003149396,	0.002962586,	0.002753836,	0.002591821]


Re_theta_earsm = [1.75E+03,	2.45E+03,	3.83E+03,	5.05E+03,	7.33E+03,	9.97E+03]

cf_earsm = [0.004271085,	0.003840916,	0.003537684,	0.003401347,	0.003279747,	0.003186662]

# Plotting both datasets
plt.plot(Re_theo, c_f_theo, marker='x', linestyle='--', color='r', label='Theoretical Data')

# Plotting both datasets
plt.plot(Re_theta_ml, c_f_ml, marker='o', linestyle='-', label='Mixing Length Model with Corase Grid')
plt.plot(Re_theta_sa, c_f_sa, marker='o', linestyle='-',  label='One Equation Model with Coarse Grid')

plt.plot(Re_theta, c_f, marker='o', linestyle='-', color='g', label=r'$k-\varepsilon$ Turbulence Model with Coarse Grid')
plt.plot(Re_theta2, c_f2, marker='o', linestyle='-', color='b', label=r'$k-\varepsilon$ Turbulence Model with Fine Grid')
plt.plot(Re_theta3, c_f3, marker='o', linestyle='-', color='cyan', label=r'$k-\omega$ Turbulence Model with Coarse Grid')
plt.plot(Re_theta4, c_f4, marker='o', linestyle='-', color='magenta', label=r'$k-\omega$ Turbulence Model with Fine Grid')
plt.plot(Re_theta_earsm, cf_earsm, marker='o', linestyle='-', label=r'EARSM Model with Corase Grid')

# Labels and title
plt.xlabel(r'$R_{e, \theta}$')
plt.ylabel(r'$C_f$')
plt.title(r'Plot of $C_f$ vs $R_{e, \theta}$')

plt.xlim(4000, 13000)

# Display grid
plt.grid(True)

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
df.columns
# Out:
# Index(['y', 'y+ ', 'u+', 'y+ theo', 'u+theo', 'Unnamed: 5', 'Unnamed: 6',
#        'y.1', 'x02', 'x04', 'x06', 'Unnamed: 11', 'y2', 'x=0.2', 'x=0.4',
#        'x=0.6', 'Unnamed: 16', 'y1+ ', 'u1+', 'Unnamed: 19', 'y+ec', 'u+ec',
#        'Unnamed: 22', 'y+oc ', 'u+oc', 'Unnamed: 25', 'y+ef ', 'u+ef',
#        'Unnamed: 28', 'y+of', 'u+of'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))

plt.plot(df['y+ '], df['u+'], linestyle='-',  label=r'Mixing Length Model with Coarse Grid ($y^+, u^+$)')
plt.plot(df['y1+ '], df['u1+'], linestyle='-',  label=r'One-Equation Model with Coarse Grid ($y^+, u^+$)')
plt.plot(df['y+ec'], df['u+ec'], linestyle='-', color='g', label=r'$k-\varepsilon$ Turbulence Model with Coarse Grid ($y^+, u^+$)')
plt.plot(df['y+ef '], df['u+ef'], linestyle='-', color='b', label=r'$k-\varepsilon$ Turbulence Model with Fine Grid ($y^+, u^+$)')
plt.plot(df['y+oc '], df['u+oc'], linestyle='-', color='cyan', label=r'$k-\omega$ Turbulence Model with Coarse Grid ($y^+, u^+$)')
plt.plot(df['y+of'], df['u+of'], linestyle='-', color='magenta', label=r'$k-\omega$ Turbulence Model with Fine Grid ($y^+, u^+$)')
plt.plot(df['y+earsmc'], df['u+earsmc'], linestyle='-', label=r'EARSM Model with Coarse Grid ($y^+, u^+$)')
plt.plot(df['y+ theo'], df['u+theo'],  linestyle='--', color='r', label=r'Theoretical ($y^+_{theo}, u^+_{theo}$)')

# Log scale for better visualization (optional for boundary layer profiles)
plt.xscale('log')

# Axis labels and title
plt.xlabel('y+ (Dimensionless Wall Distance)')
plt.ylabel('u+ (Dimensionless Velocity)')
plt.title(r'Comparison of Experimental and Theoretical $u^+$ vs $y^+$')

# Add legend and grid
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # outside right
plt.tight_layout()  # adjusts the plot to fit within the figure area
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Show the plot
plt.show()

# %%
import pandas as pd

def read_xy_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Extract column labels from the second line (assumes fixed format)
    label_x, label_y = lines[1].replace('(labels "', "").replace('")', "").split('" "')

    data_blocks = {}
    current_label = None
    data_start = False

    for line in lines:
        line = line.strip()

        # Detect new data block
        if line.startswith("((xy/key/label"):
            current_label = line.split('"')[1]  # Extract label without regex
            data_blocks[current_label] = []
            data_start = True
            continue
        
        # Stop if end of data block
        if data_start and line.endswith(")"):
            continue
        
        # Read numerical data
        if data_start and line:
            values = line.split()
            data_blocks[current_label].append([float(values[0]), float(values[1])])

    # Convert blocks into DataFrames and merge
    merged_df = None
    for i, (key, data) in enumerate(data_blocks.items()):
        df = pd.DataFrame(data, columns=[label_x, key])  # Name the second column with block label
        if merged_df is None:
            merged_df = df
        else:
            merged_df = pd.merge(merged_df, df, on=label_x, how="outer")  # Merge on the first column

    
    return merged_df, label_x


# Example usage
file_path = r"C:\Users\Korisnik\Documents\SARENA\LUT - SARENA M1S2\Turbulence Models\eddy_visc_exercise5.xy"  # Update with your actual file path
df, x_label = read_xy_file(file_path)
def plot_xy_data(df, x_label):
    plt.figure(figsize=(8, 6))

    # Plot each data block (column) against Z-Coordinate
    for col in df.columns[1:]:  # Skip first column (Z-Coordinate)
        plt.plot(df[x_label], df[col], marker='o', linestyle='-', label=col)
   
    plt.xlabel(x_label)
    plt.ylabel("Value")
    plt.title("Eddy Viscosity")
    plt.legend()
    plt.grid(True)
    plt.show()



# Example usage
df, x_label = read_xy_file(file_path)

plot_xy_data(df, x_label)

print(df)
# Out:
#      Z-Coordinate      line-x02      line-x04      line-x06
# 0    5.002330e-07  5.564120e-08  4.860970e-08  4.501770e-08
# 1    1.502560e-06  4.891450e-07  4.286740e-07  3.976400e-07
# 2    2.510480e-06  1.308120e-06  1.151880e-06  1.071170e-06
# 3    3.527740e-06  2.439660e-06  2.160440e-06  2.015120e-06
# 4    4.558140e-06  3.815140e-06  3.397500e-06  3.178690e-06
# ..            ...           ...           ...           ...
# 150  7.957790e-02  1.607840e-03  9.223780e-04  7.144530e-04
# 151  8.458320e-02  1.806170e-03  1.042380e-03  8.079400e-04
# 152  8.990340e-02  2.027050e-03  1.177680e-03  9.135300e-04
# 153  9.555820e-02  2.272790e-03  1.330410e-03  1.033020e-03
# 154  1.015690e-01  2.545500e-03  1.502450e-03  1.167960e-03
#
# [155 rows x 4 columns]
